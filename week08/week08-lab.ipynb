# %% [markdown]
# <div style="text-align: center;">
#
# # **Spring 2026 &mdash; CIS 3813<br>Advanced Data Science<br>(Introduction to Machine Learning)**
# ### Week 8: Naïve Bayes & Support Vector Machines
#
# </div>

# %% [markdown]
# ---
#
# ## **Lab Instructions**
#
# **Due Date**: Monday, 30 March @ 6:00 PM (with grace period until Wednesday, 01 April @ 11:59 PM)
#
# **AI Usage**:
# - You may use AI tools for this lab
# - **REQUIRED**: Include AI attribution using the format shown in the syllabus
# - For B/A level credit, include detailed attribution in markdown cells
#
# ## **Grading**
#
# | Component | Points |
# |-----------|--------|
# | Exercise 1: Setup & Data Exploration | 10 |
# | Exercise 2: Naïve Bayes for Text Classification | 20 |
# | Exercise 3: Gaussian Naïve Bayes on Structured Data | 15 |
# | Exercise 4: Support Vector Machines | 20 |
# | Exercise 5: Algorithm Comparison | 15 |
# | Reflection | 10 |
# | **In-Class Mastery Assessment (Week 8)** | **10 (Assessed in class)** |
# | **Total** | **100** |

# %% [markdown]
# ---
#
# ## **AI Assistance Declaration**
#
# **Tools used:** [ChatGPT-4 / GitHub Copilot / Claude / None / Other — update this]
#
# **Sections with AI help:** [e.g., "Exercise 3, Task 3.2" — update this]
#
# **What I learned:** [Brief description — update this]
#
# **What I did independently:** [Sections completed without AI — update this]

# %% [markdown]
# ---
#
# ## **Exercise 1 — Setup & Data Exploration (10 points)**
#
# ### **Task 1.1 — Load Libraries and Dataset (3 pts)**
#
# This lab uses the **SMS Spam Collection dataset** — a set of 5,574 SMS messages labeled as `ham` (legitimate) or `spam`. It is a classic benchmark for text classification and a natural domain for Naïve Bayes.
#
# Run the cell below to load all libraries and data you will need throughout the lab.

# %%
# Run this cell — it loads all libraries and data you'll need
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from sklearn.naive_bayes import MultinomialNB, BernoulliNB, GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, ConfusionMatrixDisplay, classification_report,
    roc_curve, roc_auc_score
)

# Set plotting style
plt.rcParams['figure.figsize'] = (10, 6)
print("Libraries imported successfully!")

# Load the SMS Spam Collection dataset
url = "https://raw.githubusercontent.com/justmarkham/pycon-2016-tutorial/master/data/sms.tsv"
df = pd.read_csv(url, sep='\t', header=None, names=['label', 'message'])

print("Dataset loaded successfully!")
print(f"Shape: {df.shape}")
df.head(10)

# %% [markdown]
# ### **Task 1.2 — Explore the Dataset (4 pts)**
#
# Before building any model, understand what you're working with. **Your task:**
# 1. Print the count and percentage of each class (`ham` vs. `spam`)
# 2. Create a bar chart showing the class distribution
# 3. Print the average message length (in characters) for ham and spam messages separately
#
# *(4 pts — 1 pt per task + 1 pt for observations below)*

# %%
# YOUR CODE HERE
# 1. Count and percentage of each class

# %%
# 2. Bar chart of class distribution

# %%
# 3. Average message length by class
# Hint: df['message'].str.len() gives character counts

# %% [markdown]
# **Your observations (2-3 sentences) — Is the dataset balanced? Are spam messages longer or shorter than ham? Does that surprise you?**
#
# *[Double-click this cell to type your answer here]*

# %% [markdown]
# ### **Task 1.3 — Prepare Train/Test Split (3 pts)**
#
# **Your task:**
# 1. Encode the `label` column as binary: `ham` → 0, `spam` → 1 and assign to `y`
# 2. Assign the `message` column to `X`
# 3. Create an 80/20 train/test split using `stratify=y`
# 4. Print the class distribution in both the train and test sets to confirm stratification worked
#
# *(3 pts)*

# %%
# YOUR CODE HERE
# 1. Encode labels: ham=0, spam=1
y =

# 2. Assign messages to X
X =

# 3. Train/test split with stratification
X_train, X_test, y_train, y_test =

# 4. Confirm class distribution
print("Training set class distribution:")

print("Test set class distribution:")

# %% [markdown]
# ---
# ## **Exercise 2 — Naïve Bayes for Text Classification (20 points)**
#
# ### **Task 2.1 — Multinomial Naïve Bayes Pipeline (6 pts)**
#
# Build a text classification pipeline using **Multinomial Naïve Bayes** with word count features.
#
# **Your task:**
# 1. Build a `Pipeline` with `CountVectorizer(stop_words='english')` and `MultinomialNB()`
# 2. Fit the pipeline on the training data
# 3. Generate predictions on the test set
# 4. Print the full `classification_report` with labels `['ham', 'spam']`
#
# *(6 pts — 3 pts for correct pipeline, 2 pts for fit/predict, 1 pt for report)*

# %%
# YOUR CODE HERE
# 1. Build the Multinomial NB pipeline
mnb_pipeline =

# 2. Fit

# 3. Predict
y_pred_mnb =

# 4. Classification report

# %% [markdown]
# ### **Task 2.2 — Most Informative Words (7 pts)**
#
# One of Naïve Bayes's greatest strengths is interpretability — you can directly inspect which words most strongly signal each class.
#
# **Your task:**
# 1. Extract the vocabulary from your fitted `CountVectorizer` using `get_feature_names_out()`
# 2. Extract the log-probability matrix from your fitted `MultinomialNB` using `feature_log_prob_`
# 3. Print the **top 15 most informative words** for both `ham` (class 0) and `spam` (class 1)
# 4. Create a horizontal bar chart showing the top 15 spam-indicator words and their log-probabilities
#
# Hint: `feature_log_prob_[1]` gives log-probabilities for class 1 (spam).
#
# *(7 pts — 3 pts for word extraction, 4 pts for bar chart)*

# %%
# YOUR CODE HERE
# 1. Extract vocabulary
vocab =

# 2. Extract log-probability matrix
log_probs =

# 3. Top 15 words for ham and spam
print("Top 15 ham words:")

print("\nTop 15 spam words:")

# %%
# 4. Horizontal bar chart — top 15 spam-indicator words
# YOUR PLOT CODE HERE

# %% [markdown]
# **Your observations (2-3 sentences) — Do the top spam words make intuitive sense? Are there any surprising words on either list?**
#
# *[Double-click this cell to type your answer here]*

# %% [markdown]
# ### **Task 2.3 — Multinomial vs. Bernoulli NB (7 pts)**
#
# The lecture introduced three NB variants. Multinomial NB uses word *counts*; Bernoulli NB uses only word *presence or absence* (binary). Let's compare them.
#
# **Your task:**
# 1. Build a second pipeline using `CountVectorizer(stop_words='english', binary=True)` and `BernoulliNB()`
# 2. Fit and evaluate it on the same train/test split
# 3. Create a **side-by-side confusion matrix** plot comparing Multinomial NB and Bernoulli NB (use `plt.subplots(1, 2)`)
# 4. In a markdown cell, answer: *Which variant performs better on spam detection? Why might that be the case for SMS messages specifically?*
#
# *(7 pts — 3 pts code, 4 pts confusion matrix plot + written explanation)*

# %%
# YOUR CODE HERE
# 1. Build and fit Bernoulli NB pipeline
bnb_pipeline =

# 2. Predict
y_pred_bnb =

print("=== Bernoulli NB ===")
print(classification_report(y_test, y_pred_bnb, target_names=['ham', 'spam']))

# %%
# 3. Side-by-side confusion matrices
# YOUR PLOT CODE HERE

# %% [markdown]
# **Your written answer (2-3 sentences): *Which variant performs better on spam detection? Why might that be the case for SMS messages specifically?***
#
# *[Double-click this cell to type your answer here]*

# %% [markdown]
# ---
# ## **Exercise 3 — Gaussian Naïve Bayes on Structured Data (15 points)**
#
# ### **Task 3.1 — Load the Breast Cancer Dataset (2 pts)**
#
# Gaussian NB is designed for continuous features — let's apply it to a structured medical dataset. We'll use sklearn's built-in **Breast Cancer Wisconsin** dataset, which has 30 numeric features describing tumor characteristics.
#
# Run the cell below to load the data.

# %%
# Run this cell
from sklearn.datasets import load_breast_cancer

cancer = load_breast_cancer()
X_bc = pd.DataFrame(cancer.data, columns=cancer.feature_names)
y_bc = cancer.target   # 0 = malignant, 1 = benign

print(f"Features : {X_bc.shape[1]}")
print(f"Samples  : {X_bc.shape[0]}")
print(f"Classes  : {cancer.target_names}  (0=malignant, 1=benign)")
print(f"Class counts: {np.bincount(y_bc)}")
X_bc.describe().round(3)

# %% [markdown]
# ### **Task 3.2 — Train and Evaluate Gaussian NB (7 pts)**
#
# **Your task:**
# 1. Create a 75/25 train/test split of the breast cancer data using `stratify=y_bc` and `random_state=42`
# 2. Train a `GaussianNB()` model on the training data (**no scaling needed** — Gaussian NB estimates its own per-feature distributions)
# 3. Generate predictions and predicted probabilities on the test set
# 4. Print the `classification_report` with target names `['malignant', 'benign']`
# 5. Plot the confusion matrix
#
# *(7 pts — 2 pts split, 2 pts train/predict, 3 pts report + confusion matrix)*

# %%
# YOUR CODE HERE
# 1. Train/test split
X_bc_train, X_bc_test, y_bc_train, y_bc_test =

# 2. Train GaussianNB
gnb =

# 3. Predict and get probabilities
y_bc_pred  =
y_bc_proba =

# 4. Classification report

# %%
# 5. Confusion matrix
# YOUR PLOT CODE HERE

# %% [markdown]
# ### **Task 3.3 — The Naïve Assumption in Medical Context (6 pts)**
#
# The Breast Cancer dataset has 30 features describing the same tumor — things like radius, texture, perimeter, area, and smoothness. Many of these are almost certainly correlated with each other (e.g., larger radius → larger area and perimeter).
#
# **Your task:**
# 1. Compute and print the Pearson correlation between `mean radius` and `mean area` using `X_bc[['mean radius', 'mean area']].corr()`
# 2. In a markdown cell, answer: *Does Gaussian NB's naïve independence assumption hold for these features? Given your correlation finding, why might Gaussian NB still perform reasonably well despite the violated assumption?* (4-5 sentences)
#
# *(6 pts — 2 pts code, 4 pts written)*

# %%
# YOUR CODE HERE
# 1. Correlation between mean radius and mean area

# %% [markdown]
# **Your written answer (4-5 sentences):**
#
# *[Double-click this cell to type your answer here]*

# %% [markdown]
# ---
# ## **Exercise 4 — Support Vector Machines (20 points)**
#
# ### **Task 4.1 — Linear SVM Baseline (5 pts)**
#
# We'll continue with the **Breast Cancer** dataset for this exercise. SVMs require feature scaling — be sure to use a `Pipeline` that includes `StandardScaler`.
#
# **Your task:**
# 1. Build a `Pipeline` with `StandardScaler` and `SVC(kernel='linear', probability=True, random_state=42)`
# 2. Fit and evaluate on the breast cancer train/test split from Exercise 3
# 3. Print the accuracy, F1-score, and AUC-ROC
# 4. In a markdown cell (1-2 sentences): *Why is feature scaling required for SVMs but not for Gaussian NB?*
#
# *(5 pts — 3 pts code, 2 pts written)*

# %%
# YOUR CODE HERE
# 1. Linear SVM pipeline
svm_linear_pipe =

# 2. Fit

# 3. Evaluate
y_svm_linear_pred  =
y_svm_linear_proba =

print(f"Linear SVM — Accuracy : {accuracy_score(y_bc_test, y_svm_linear_pred):.4f}")
print(f"Linear SVM — F1-Score : {f1_score(y_bc_test, y_svm_linear_pred):.4f}")
print(f"Linear SVM — AUC-ROC  : {roc_auc_score(y_bc_test, y_svm_linear_proba):.4f}")

# %% [markdown]
# **Your written answer (1-2 sentences):**
#
# *[Double-click this cell to type your answer here]*

# %% [markdown]
# ### **Task 4.2 — Effect of C on the Linear SVM (7 pts)**
#
# Recall from the lecture: **C** controls the tradeoff between margin width and training errors. A small C allows violations and produces a wider (more regularized) margin; a large C penalizes violations and produces a narrower margin.
#
# **Your task:**
# 1. Train **five** linear SVM models with `C = [0.001, 0.01, 1, 100, 10000]` (use `Pipeline` with `StandardScaler`)
# 2. For each, record: training accuracy, test accuracy, and test F1-score
# 3. Create a line plot showing training accuracy and test accuracy vs. C (use a log-scale x-axis: `ax.set_xscale('log')`)
# 4. In a markdown cell, answer: *Which value of C shows signs of overfitting? Which shows underfitting? How can you tell?* (2-3 sentences)
#
# *(7 pts — 3 pts code, 4 pts plot + written)*

# %%
# YOUR CODE HERE
C_values = [0.001, 0.01, 1, 100, 10000]
train_accs, test_accs, test_f1s = [], [], []

for C_val in C_values:
    # YOUR CODE HERE — build pipeline, fit, record metrics
    pass

# Print results table
print(f"{'C':>10} {'Train Acc':>12} {'Test Acc':>12} {'Test F1':>10}")
print("─" * 46)
for C_val, tr, te, f1 in zip(C_values, train_accs, test_accs, test_f1s):
    print(f"{C_val:>10.3f} {tr:>12.4f} {te:>12.4f} {f1:>10.4f}")

# %%
# Line plot: train accuracy and test accuracy vs. C
# YOUR PLOT CODE HERE
# Remember: use ax.set_xscale('log') for the x-axis

# %% [markdown]
# **Your written answer (2-3 sentences):**
#
# *[Double-click this cell to type your answer here]*

# %% [markdown]
# ### **Task 4.3 — RBF Kernel and Grid Search (8 pts)**
#
# The RBF kernel can capture non-linear patterns. It introduces a second hyperparameter — **γ (gamma)** — that controls how quickly similarity falls off with distance. We need to tune both C and γ together.
#
# **Your task:**
# 1. Build a `Pipeline` with `StandardScaler` and `SVC(kernel='rbf', probability=True, random_state=42)`
# 2. Define a `param_grid` with:
#    - `svm__C`: `[0.1, 1, 10, 100]`
#    - `svm__gamma`: `[0.001, 0.01, 0.1, 1]`
# 3. Run `GridSearchCV` with `cv=5` and `scoring='roc_auc'`
# 4. Print the best parameters and best CV score
# 5. Evaluate the best model on the test set — print accuracy, F1, and AUC-ROC
#
# *(8 pts — 4 pts grid search code, 4 pts results and evaluation)*

# %%
# YOUR CODE HERE
# 1. Build the RBF SVM pipeline
svm_rbf_pipe =

# 2. Define the parameter grid
param_grid =

# 3. GridSearchCV
gs_rbf =

# Fit

# 4. Print best params and best CV score
print(f"Best params  : {gs_rbf.best_params_}")
print(f"Best CV AUC  : {gs_rbf.best_score_:.4f}")

# %%
# 5. Evaluate best model on test set
# YOUR CODE HERE
best_rbf_model =
y_rbf_pred  =
y_rbf_proba =

print(f"RBF SVM (best) — Accuracy : {accuracy_score(y_bc_test, y_rbf_pred):.4f}")
print(f"RBF SVM (best) — F1-Score : {f1_score(y_bc_test, y_rbf_pred):.4f}")
print(f"RBF SVM (best) — AUC-ROC  : {roc_auc_score(y_bc_test, y_rbf_proba):.4f}")

# %% [markdown]
# ---
# ## **Exercise 5 — Algorithm Comparison (15 points)**
#
# ### **Task 5.1 — Build a Metrics Summary Table (8 pts)**
#
# You now have four models evaluated on the Breast Cancer test set:
# - Gaussian Naïve Bayes (Exercise 3)
# - Linear SVM (Exercise 4.1)
# - RBF SVM (best from grid search, Exercise 4.3)
# - Logistic Regression (for comparison — train it now using a pipeline with `StandardScaler` and `LogisticRegression(max_iter=1000, random_state=42)`)
#
# **Your task:**
# 1. Train the Logistic Regression baseline
# 2. Build a summary `DataFrame` comparing all four models on: Accuracy, Precision, Recall, F1-Score, and AUC-ROC
# 3. Display the DataFrame
#
# *(8 pts — 2 pts LR baseline, 6 pts summary table)*

# %%
# YOUR CODE HERE
# 1. Train Logistic Regression baseline
lr_pipe =

y_lr_pred  =
y_lr_proba =

# %%
# 2 & 3. Build and display summary DataFrame
# YOUR CODE HERE

# Hint: build a dict like:
# results = {
#     'Model':     ['Gaussian NB', 'Linear SVM', 'RBF SVM', 'Logistic Reg'],
#     'Accuracy':  [...],
#     'Precision': [...],
#     ...etc
# }
# Then pd.DataFrame(results)

# %% [markdown]
# ### **Task 5.2 — ROC Curve Comparison (7 pts)**
#
# **Your task:**
# 1. Plot the ROC curves for all four models on a single figure, each in a different color and labeled with its AUC score
# 2. Include the random classifier diagonal (dashed line) and a shaded area under the best-performing curve
# 3. In a markdown cell, answer: *Which model would you recommend for a cancer screening tool — and which metric most influenced your decision? Justify your answer in 3-4 sentences, referencing the tradeoff between false positives and false negatives in this medical context.*
#
# *(7 pts — 4 pts plot, 3 pts written)*

# %%
# ROC curve comparison — all four models on one plot
# YOUR PLOT CODE HERE

# Hint: loop over a dict like:
# model_probas = {
#     'Gaussian NB':  y_bc_proba,
#     'Linear SVM':   y_svm_linear_proba,
#     'RBF SVM':      y_rbf_proba,
#     'Logistic Reg': y_lr_proba,
# }
# Then for each, call roc_curve() and plot fpr vs. tpr

# %% [markdown]
# **Your written answer (3-4 sentences):**
#
# *[Double-click this cell to type your answer here]*

# %% [markdown]
# ---
# ## **Exercise 6 — Reflection (10 points)**
#
# ### **Task 6.1 — Technical Reflection (4 pts)**
#
# In 4-5 sentences, reflect on: *Looking at your results across Exercises 2–5, when did Naïve Bayes perform surprisingly well and when did SVMs outperform it? Based on your experiments, what properties of a dataset or problem make Naïve Bayes a good first choice versus when you would reach for an SVM?*
#
# *(4 pts — quality of reasoning, references to specific results)*

# %% [markdown]
# **Your technical reflection:**
#
# *[Double-click this cell to type your answer here]*

# %% [markdown]
# ### **Task 6.2 — Ethical Reflection (3 pts)**
#
# This lab applied classifiers to medical data (breast cancer diagnosis) where predictions directly affect patient outcomes. In 3-4 sentences, reflect on: *The Breast Cancer dataset was collected from patients — real people with diagnoses, fears, and medical histories. What ethical responsibilities does a data scientist have when building classifiers on medical data? What could go wrong if a model is deployed without careful evaluation?*
#
# *(3 pts)*

# %% [markdown]
# **Your ethical reflection:**
#
# *[Double-click this cell to type your answer here]*

# %% [markdown]
# ### **Task 6.3 — Faith Integration Reflection (3 pts)**
#
# Recall this week's verse: *"For the Lord gives wisdom; from his mouth come knowledge and understanding."* — Proverbs 2:6
#
# In 3-4 sentences, connect this verse to what you experienced in this lab. *Naïve Bayes begins with prior beliefs and updates them with evidence. SVMs focus entirely on the hardest, most ambiguous cases. What does it mean to approach knowledge — whether in data science or in life — with the kind of wisdom Proverbs 2:6 describes? How might the practice of building and evaluating classifiers be an exercise in intellectual humility?*
#
# *(3 pts)*

# %% [markdown]
# **Your faith integration reflection:**
#
# *[Double-click this cell to type your answer here]*

# %% [markdown]
# ## **Submission Checklist**
# Before submitting, confirm:
# - [ ] AI Attribution Declaration is completed at the top of the notebook
# - [ ] All code cells run without errors (Kernel → Restart & Run All)
# - [ ] All written responses are filled in (no cells still say "Double-click to type")
# - [ ] All plots have titles, axis labels, and legends
# - [ ] Notebook is submitted to Canvas before Monday 6:00 PM
#
# **Lab due:** Monday, 30 March @ 6:00 PM (Grace period: Wednesday, 01 April @ 11:59 PM)
